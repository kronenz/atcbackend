# %%
from ncclient import manager
from ncclient.xml_ import to_ele
import json
import xmltodict,json

# %%
klm_host = "10.0.20.150"
klm_user = "admin"
klm_pwd = "Forwiz_SDF1"

rpc = '<get></get>'
with manager.connect(host=host, port=830, username=user, password=pwd, hostkey_verify=False) as m:
    c = m.get().xml

# %%
with manager.connect(host=host, port=830, username=user, password=pwd, hostkey_verify=False) as m:
    rpc = """<GetPacketCounters xmlns="urn:kaloom:faas:fabrics"></GetPacketCounters>"""
    c = m.rpc(to_ele(rpc)).xml

# %%
res_dict=xmltodict.parse(c)

# %%
res_dict['rpc-reply']['fabrics:Results']
# Out:
# [{'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p20s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120293447'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p27s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120569045'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p28s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120611798'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p5s2',
#   'fabrics:RxBytes': '90371885843',
#   'fabrics:TxBytes': '67455441235',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '175341999',
#   'fabrics:TxPackets': '309354910',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120880146'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p11s4',
#   'fabrics:RxBytes': '127277994',
#   'fabrics:TxBytes': '388483073193',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '448103',
#   'fabrics:TxPackets': '581687472',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120022979'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p21s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120318432'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p22s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120382051'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p32s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120791182'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p12s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120040425'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p12s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120034742'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p14s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120094793'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p22s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120363120'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p30s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120732529'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p10s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900119956089'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p5s3',
#   'fabrics:RxBytes': '100516869169',
#   'fabrics:TxBytes': '88107042197',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '184617423',
#   'fabrics:TxPackets': '319451234',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120883511'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p7s3',
#   'fabrics:RxBytes': '69010980238',
#   'fabrics:TxBytes': '141004492377',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '155760129',
#   'fabrics:TxPackets': '354950224',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120913699'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p2s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120677879'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p12s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120046382'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p10s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120000634'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p30s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120713277'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p1s4',
#   'fabrics:RxBytes': '81281663800',
#   'fabrics:TxBytes': '25044509185',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '194534775',
#   'fabrics:TxPackets': '30033417',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120274259'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p25s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120466954'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p8s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120934429'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p14s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120088325'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p7s2',
#   'fabrics:RxBytes': '96819582438',
#   'fabrics:TxBytes': '145370715699',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '181293659',
#   'fabrics:TxPackets': '366992194',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120909716'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p27s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120547915'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p18s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120212706'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p8s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120926034'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p14s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120081952'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p19s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120259669'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p21s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120336328'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p26s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120527030'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p16s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120168193'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p27s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120579600'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p31s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120779437'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p5s4',
#   'fabrics:RxBytes': '104630809980',
#   'fabrics:TxBytes': '84651367726',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '180906049',
#   'fabrics:TxPackets': '317995760',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120886836'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p15s4',
#   'fabrics:RxBytes': '28044640104',
#   'fabrics:TxBytes': '64329634190',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '164218010',
#   'fabrics:TxPackets': '164057025',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120139703'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p24s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120437914'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p3s2',
#   'fabrics:RxBytes': '57174817030',
#   'fabrics:TxBytes': '23656377558',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '185792411',
#   'fabrics:TxPackets': '24127780',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120854928'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p5s1',
#   'fabrics:RxBytes': '91819816610',
#   'fabrics:TxBytes': '81467947777',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '176688821',
#   'fabrics:TxPackets': '319532715',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120877093'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p17s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120190571'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p25s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120486359'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p16s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120146488'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p22s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120348090'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p24s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120428614'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p2s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120680256'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p2s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120683009'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p30s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120699706'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p31s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120767817'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p11s3',
#   'fabrics:RxBytes': '115499797',
#   'fabrics:TxBytes': '228078526',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '411367',
#   'fabrics:TxPackets': '554018',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120017157'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p9s2',
#   'fabrics:RxBytes': '124759796',
#   'fabrics:TxBytes': '652328766',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '443799',
#   'fabrics:TxPackets': '923144',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120943444'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p8s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120930251'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p23s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120400333'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p23s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120410173'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p25s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120476659'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p18s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120227864'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p23s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120391178'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p19s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120243722'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p2s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120685719'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p32s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120840000'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p15s2',
#   'fabrics:RxBytes': '30065743718',
#   'fabrics:TxBytes': '68895824178',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '175803949',
#   'fabrics:TxPackets': '176110342',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120114603'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p3s3',
#   'fabrics:RxBytes': '99443334286',
#   'fabrics:TxBytes': '12809196390',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '209420491',
#   'fabrics:TxPackets': '16917922',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120858148'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p4s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120873586'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p1s1',
#   'fabrics:RxBytes': '55348132799',
#   'fabrics:TxBytes': '57937549962',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '179422647',
#   'fabrics:TxPackets': '47339208',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120268149'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p13s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120058035'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p17s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120183139'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p17s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120197779'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p19s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120251787'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p9s4',
#   'fabrics:RxBytes': '119070425',
#   'fabrics:TxBytes': '365121012',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '419943',
#   'fabrics:TxPackets': '862474',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120952819'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p12s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120028524'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p32s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120827820'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p1s2',
#   'fabrics:RxBytes': '462103311489',
#   'fabrics:TxBytes': '14779559324',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '768283550',
#   'fabrics:TxPackets': '20930740',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120270072'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p1s3',
#   'fabrics:RxBytes': '60239475478',
#   'fabrics:TxBytes': '428176444639',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '183441299',
#   'fabrics:TxPackets': '1159073583',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120272167'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p26s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120506429'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p28s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120601160'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p14s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120075842'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p13s4',
#   'fabrics:RxBytes': '28431908841',
#   'fabrics:TxBytes': '66658101131',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '166267802',
#   'fabrics:TxPackets': '168851630',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120069810'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p16s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120153948'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p4s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120864306'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p7s4',
#   'fabrics:RxBytes': '76424853838',
#   'fabrics:TxBytes': '92200351718',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '165396072',
#   'fabrics:TxPackets': '320410564',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120917644'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p10s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900119983836'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p3s4',
#   'fabrics:RxBytes': '105618830213',
#   'fabrics:TxBytes': '33895810521',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '213482876',
#   'fabrics:TxPackets': '30398513',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120861218'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p16s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120160961'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p15s3',
#   'fabrics:RxBytes': '28726811718',
#   'fabrics:TxBytes': '71777667184',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '165767298',
#   'fabrics:TxPackets': '182318565',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120132743'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p21s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120327700'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p24s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120447384'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p30s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120688576'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p11s2',
#   'fabrics:RxBytes': '136868584',
#   'fabrics:TxBytes': '1540579272',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '465500',
#   'fabrics:TxPackets': '2750471',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120011829'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p26s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120537592'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p4s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120870538'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p6s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120897849'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p6s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120901479'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p8s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120921766'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p9s3',
#   'fabrics:RxBytes': '119450823',
#   'fabrics:TxBytes': '333920184',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '415665',
#   'fabrics:TxPackets': '670120',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120948254'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p15s1',
#   'fabrics:RxBytes': '31923061867',
#   'fabrics:TxBytes': '64913035858',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '179389188',
#   'fabrics:TxPackets': '166449662',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120103333'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p11s1',
#   'fabrics:RxBytes': '116314786',
#   'fabrics:TxBytes': '1043954491',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '416273',
#   'fabrics:TxPackets': '3301128',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120006312'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p18s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120220241'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p32s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120815508'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p6s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120890528'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p10s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900119992602'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p7s1',
#   'fabrics:RxBytes': '73774319056',
#   'fabrics:TxBytes': '116234366229',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '161481579',
#   'fabrics:TxPackets': '346665515',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120905856'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p13s1',
#   'fabrics:RxBytes': '453689054882',
#   'fabrics:TxBytes': '66780354080',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '779717060',
#   'fabrics:TxPackets': '167914225',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120052285'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p27s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120558627'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p31s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120744424'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p3s1',
#   'fabrics:RxBytes': '84019419515',
#   'fabrics:TxBytes': '841835971420',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '193432056',
#   'fabrics:TxPackets': '1224916838',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120852318'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p26s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120516537'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p21s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120310070'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p23s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120419384'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p29s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120655646'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p6s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120894093'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p17s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120176001'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p20s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120285140'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p24s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120457116'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p28s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120590185'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p29s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120644416'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p29s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120666721'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p4s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120867166'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p9s1',
#   'fabrics:RxBytes': '426187576724',
#   'fabrics:TxBytes': '1211967341',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '614225913',
#   'fabrics:TxPackets': '5873517',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120938849'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p18s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120205286'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p19s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120235952'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p22s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120373183'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p25s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120496432'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p29s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120633483'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p31s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120756000'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p13s3',
#   'fabrics:RxBytes': '29411115611',
#   'fabrics:TxBytes': '69717319354',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '166581982',
#   'fabrics:TxPackets': '175265781',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120063945'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p20s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120301562'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p28s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120622333'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#   'fabrics:TpID': 'sw1p20s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120277055'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p10s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120275414'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p3s2',
#   'fabrics:RxBytes': '63768778963',
#   'fabrics:TxBytes': '19607853149',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '182425658',
#   'fabrics:TxPackets': '20909043',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900121098574'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p15s4',
#   'fabrics:RxBytes': '29567707233',
#   'fabrics:TxBytes': '58545485542',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '166320317',
#   'fabrics:TxPackets': '148062131',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120402125'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p19s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120522294'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p4s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900121109379'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p15s1',
#   'fabrics:RxBytes': '743303837268',
#   'fabrics:TxBytes': '458401503447',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '2468505390',
#   'fabrics:TxPackets': '745817734',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120382900'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p16s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120408683'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p25s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120762077'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p6s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900121135172'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p20s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900120568797'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#   'fabrics:TpID': 'sw1p32s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
# ...
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242047501'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p7s2',
#   'fabrics:RxBytes': '66047653028',
#   'fabrics:TxBytes': '27345707650',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '168072883',
#   'fabrics:TxPackets': '167581145',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245438568'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p26s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242993178'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p29s1',
#   'fabrics:RxBytes': '175406272',
#   'fabrics:TxBytes': '312702',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '1163693',
#   'fabrics:TxPackets': '4469',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243492130'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p26s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243038114'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p31s1',
#   'fabrics:RxBytes': '4366772',
#   'fabrics:TxBytes': '57673578',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '54803',
#   'fabrics:TxPackets': '900867',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900244214667'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p29s3',
#   'fabrics:RxBytes': '299829584',
#   'fabrics:TxBytes': '4276475',
#   'fabrics:DroppedBytes': '171604566',
#   'fabrics:RxPackets': '2979279',
#   'fabrics:TxPackets': '56087',
#   'fabrics:DroppedPackets': '1137203',
#   'fabrics:Timestamp': '1667206900243580726'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p6s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245367690'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p25s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242760528'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p25s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242806178'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p23s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242509212'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p9s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245604053'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p19s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241746132'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p23s2',
#   'fabrics:RxBytes': '209067262426',
#   'fabrics:TxBytes': '729606920818',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '2376345207',
#   'fabrics:TxPackets': '2264319879',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242467884'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p3s1',
#   'fabrics:RxBytes': '442837009646',
#   'fabrics:TxBytes': '726700073125',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '720540361',
#   'fabrics:TxPackets': '2417282013',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900244908576'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p9s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245623993'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p12s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900239977128'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p28s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243445374'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p24s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242591740'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p28s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243300760'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p28s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243387451'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p15s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900240826649'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p17s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241318036'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p30s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900244080715'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p31s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900244508773'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p5s4',
#   'fabrics:RxBytes': '63887102767',
#   'fabrics:TxBytes': '25695114829',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '161323858',
#   'fabrics:TxPackets': '158293825',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245287476'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p1s1',
#   'fabrics:RxBytes': '55337896940',
#   'fabrics:TxBytes': '26128396667',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '139794986',
#   'fabrics:TxPackets': '160818283',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241794877'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p30s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243789949'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p17s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241358874'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p31s2',
#   'fabrics:RxBytes': '2472397',
#   'fabrics:TxBytes': '68703057',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '28415',
#   'fabrics:TxPackets': '222134',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900244280335'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p9s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245644003'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p11s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900239891104'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p13s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900240122772'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p18s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241473295'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p28s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900243343625'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p25s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242890917'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p10s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900239784788'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p1s3',
#   'fabrics:RxBytes': '54112455473',
#   'fabrics:TxBytes': '26087243065',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '136672963',
#   'fabrics:TxPackets': '160621986',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241856778'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p25s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242848906'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p31s3',
#   'fabrics:RxBytes': '2508704',
#   'fabrics:TxBytes': '57505039',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '28798',
#   'fabrics:TxPackets': '898231',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900244369744'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p4s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245100964'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p14s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900240266629'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p20s1',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241915926'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p24s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242632673'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p4s4',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900245137972'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p20s2',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900241965282'},
#  {'fabrics:FabricID': '123',
#   'fabrics:NodeID': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#   'fabrics:TpID': 'sw1p22s3',
#   'fabrics:RxBytes': '0',
#   'fabrics:TxBytes': '0',
#   'fabrics:DroppedBytes': '0',
#   'fabrics:RxPackets': '0',
#   'fabrics:TxPackets': '0',
#   'fabrics:DroppedPackets': '0',
#   'fabrics:Timestamp': '1667206900242343984'}]

# %%
"a"
# Out:
# 'a'

# %%
xmltodict.parse(str)
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 xmltodict.parse(str)
#
# File ~\anaconda3\lib\site-packages\xmltodict.py:378, in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, process_comments, **kwargs)
#     376     parser.Parse(b'',True)
#     377 else:
# --> 378     parser.Parse(xml_input, True)
#     379 return handler.item
#
# ExpatError: junk after document element: line 1, column 1232

# %%
pip install ncclient
# Out:
# Collecting ncclientNote: you may need to restart the kernel to use updated packages.
#   Downloading ncclient-0.6.13.tar.gz (105 kB)
# Requirement already satisfied: setuptools>0.6 in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (61.2.0)
# Requirement already satisfied: paramiko>=1.15.0 in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (2.8.1)
#
# Requirement already satisfied: lxml>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (4.8.0)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (1.16.0)
# Requirement already satisfied: pynacl>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient) (1.4.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\users\hp\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient) (3.2.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient) (3.4.8)
# Requirement already satisfied: cffi>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (2.21)
# Building wheels for collected packages: ncclient
#   Building wheel for ncclient (setup.py): started
#   Building wheel for ncclient (setup.py): finished with status 'done'
#   Created wheel for ncclient: filename=ncclient-0.6.13-py2.py3-none-any.whl size=84645 sha256=b9de5b910b7fa1aa9a1cd3e6b8135c6226d548d27c3d06a67bc8e1c1ec3c8bab
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\09\6a\19\71c39c626047324b1b4a66766ea7d03123d3cb1f8f1c2233d8
# Successfully built ncclient
# Installing collected packages: ncclient
# Successfully installed ncclient-0.6.13

# %%
pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
c.parse()

# %%
m.connected
# Out:
# False

# %%
"c"
# Out:
# 'c'

# %%
def kaloom_netconf_rpc(rpc):
        with manager.connect(host=klm_host, port=830, username=klm_user, password=klm_pwd, hostkey_verify=False) as m:
            c = m.rpc(to_ele(rpc)).xml
            parsed_data = xmltodict.parse(c)['rpc-reply']
            return parsed_data
        return {"error": "cannot process the request"}

# %%
rpc="""<get xmlns="urn:kaloom:faas:port-attributes"></get>"""

# %%
kaloom_netconf_rpc(rpc)
# Out:
# {'@xmlns:nc': 'urn:ietf:params:xml:ns:netconf:base:1.0',
#  '@message-id': 'urn:uuid:8dba02ab-03c8-4bfc-a0de-9d40c4ec3883',
#  '@xmlns': 'urn:ietf:params:xml:ns:netconf:base:1.0',
#  'data': {'@xmlns:fabrics': 'urn:kaloom:faas:fabrics',
#   '@xmlns:pa': 'urn:kaloom:faas:port-attributes',
#   'fabrics:telemetry-system': {'fabrics:enabled': 'true',
#    'fabrics:collector': {'fabrics:address': '192.168.40.60',
#     'fabrics:port': '4171',
#     'fabrics:next-hop-mac-address': '52:93:8e:e6:96:e0'},
#    'fabrics:flow': [{'fabrics:name': 'POSTECH_INT',
#      'fabrics:priority': '1',
#      'fabrics:destination-address-prefix': '192.168.53.107/32',
#      'fabrics:exclude-filter': 'false',
#      'fabrics:sample-percentage': '100'},
#     {'fabrics:name': 'ICMP_TEST',
#      'fabrics:priority': '3',
#      'fabrics:destination-address-prefix': '0.0.0.0/0',
#      'fabrics:protocol': '1',
#      'fabrics:exclude-filter': 'false',
#      'fabrics:sample-percentage': '100'},
#     {'fabrics:name': 'INT_TEST',
#      'fabrics:priority': '2',
#      'fabrics:destination-address-prefix': '0.0.0.0/0',
#      'fabrics:exclude-filter': 'false',
#      'fabrics:sample-percentage': '0'}]},
#   'fabrics:Fabric': {'fabrics:FabricID': '123',
#    'fabrics:Hostname': None,
#    'fabrics:Name': 'Fabric-123',
#    'fabrics:Description': None,
#    'fabrics:Timezone': 'America/Montreal',
#    'fabrics:Quorum': '3',
#    'fabrics:NbControllers': '3',
#    'fabrics:EnableGUI': 'true',
#    'fabrics:TopologyOperStatus': {'fabrics:TopologyClass': 'InvalidTopology',
#     'fabrics:Valid': 'false',
#     'fabrics:ValidityCount': '4',
#     'fabrics:Error': 'UnevenLinkCardinality'},
#    'fabrics:OutOfBandManagementNetwork': {'fabrics:InterfaceName': 'netd10af457daa1',
#     'fabrics:VlanID': '20',
#     'fabrics:IPv4': {'fabrics:NetworkPrefix': '10.0.20.0/24',
#      'fabrics:LowerAddress': '10.0.20.150',
#      'fabrics:UpperAddress': '10.0.20.170',
#      'fabrics:Gateway': '10.0.20.254',
#      'fabrics:ManagementAddress': '10.0.20.150',
#      'fabrics:GUIAddress': '10.0.20.156'},
#     'fabrics:IPv6': {'fabrics:NetworkPrefix': '2602:807:900e:1d2::/64',
#      'fabrics:LowerAddress': '2602:807:900e:1d2::1',
#      'fabrics:UpperAddress': '2602:807:900e:1d2:ffff:ffff:ffff:ffff',
#      'fabrics:Gateway': '2602:807:900e:1d2::1',
#      'fabrics:ManagementAddress': '2602:807:900e:1d2::2',
#      'fabrics:GUIAddress': '2602:807:900e:1d2::8'}},
#    'fabrics:Node': [{'fabrics:NodeID': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:Hostname': 'leaf-3',
#      'fabrics:Name': 'leaf-3',
#      'fabrics:Description': None,
#      'fabrics:DeviceID': '622692977828',
#      'fabrics:DeviceMAC': '00:90:fb:64:cc:a4',
#      'fabrics:Role': 'LEAF',
#      'fabrics:MACAddressBase': 'b8:6a:97:96:25:ec',
#      'fabrics:MACAddressCount': '132',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:System': {'fabrics:SystemUptime': '01:00:37 up 14 days, 22:20,  0 users,  load average: 3.46, 3.49, 3.71',
#       'fabrics:SystemClock': 'Tue Nov  1 01:00:37 UTC 2022',
#       'fabrics:SystemMemory': {'fabrics:MemTotal': '8043648',
#        'fabrics:MemFree': '68416',
#        'fabrics:Cached': '4473632',
#        'fabrics:SwapCached': '0',
#        'fabrics:SwapTotal': '0',
#        'fabrics:SwapFree': '0'}},
#      'fabrics:Hardware': {'fabrics:Polling': {'fabrics:Interval': '30'}},
#      'fabrics:TerminationPoint': [{'fabrics:TpID': 'sw1p29s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:5e',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '150'}},
#       {'fabrics:TpID': 'sw1p14s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:22',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '22'}},
#       {'fabrics:TpID': 'sw1p29s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:5c',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '148'}},
#       {'fabrics:TpID': 'sw1p13s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:1d',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '29'}},
#       {'fabrics:TpID': 'sw1p24s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:4a',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '58'}},
#       {'fabrics:TpID': 'sw1p28s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:5a',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '166'}},
#       {'fabrics:TpID': 'sw1p2s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f3',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '139'}},
#       {'fabrics:TpID': 'sw1p1s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:ee',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '130'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s3'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'}]},
#       {'fabrics:TpID': 'sw1p18s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:32',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '10'}},
#       {'fabrics:TpID': 'sw1p14s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:21',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '21'}},
#       {'fabrics:TpID': 'sw1p4s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f8',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '152'}},
#       {'fabrics:TpID': 'sw1p3s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f5',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '145'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s2'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'}]},
#       {'fabrics:TpID': 'sw1p7s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:05',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '177'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccd2'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s2'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'}]},
#       {'fabrics:TpID': 'sw1p31s4',
#        'fabrics:Name': 'LF3-31-4:ZT_ESXi5-1',
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'USER_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:67',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '135'}},
#       {'fabrics:TpID': 'sw1p4s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f9',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '153'}},
#       {'fabrics:TpID': 'sw1p3s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f4',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '144'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s1'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'}]},
#       {'fabrics:TpID': 'sw1p8s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:0b',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '187'}},
#       {'fabrics:TpID': 'sw1p21s1',
#        'fabrics:Name': 'LF3-21-1:ESXi1-1',
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'USER_PORT',
#        'fabrics:Bandwidth': '10G',
#        'fabrics:BandwidthState': '10G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'NONE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:3c',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '32'},
#         {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#          'fabrics:Value': '3c:fd:fe:b9:f6:64'},
#         {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#          'fabrics:Value': '3c:fd:fe:b9:f6:64'}]},
#       {'fabrics:TpID': 'sw1p16s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:29',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '5'}},
#       {'fabrics:TpID': 'sw1p32s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:6b',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '143'}},
#       {'fabrics:TpID': 'sw1p26s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:52',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '182'}},
#       {'fabrics:TpID': 'sw1p10s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:13',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '55'}},
#       {'fabrics:TpID': 'sw1p1s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:ec',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '128'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s1'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'}]},
#       {'fabrics:TpID': 'sw1p20s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:3b',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '27'}},
#       {'fabrics:TpID': 'sw1p14s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:23',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '23'}},
#       {'fabrics:TpID': 'sw1p27s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:57',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '175'}},
#       {'fabrics:TpID': 'sw1p12s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:18',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '36'}},
#       {'fabrics:TpID': 'sw1p22s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:42',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '42'}},
#       {'fabrics:TpID': 'sw1p24s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:48',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '56'}},
#       {'fabrics:TpID': 'sw1p11s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:14',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '44'}},
#       {'fabrics:TpID': 'sw1p25s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:4f',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '191'}},
#       {'fabrics:TpID': 'sw1p10s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:10',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '52'}},
#       {'fabrics:TpID': 'sw1p30s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:60',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '156'}},
#       {'fabrics:TpID': 'sw1p32s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:6a',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '142'}},
#       {'fabrics:TpID': 'sw1p24s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:49',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '57'}},
#       {'fabrics:TpID': 'sw1p6s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:02',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '170'}},
#       {'fabrics:TpID': 'sw1p8s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:09',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '185'}},
#       {'fabrics:TpID': 'sw1p21s2',
#        'fabrics:Name': 'LF3-21-2:ESXi2-1',
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'USER_PORT',
#        'fabrics:Bandwidth': '10G',
#        'fabrics:BandwidthState': '10G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'NONE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:3d',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '33'}},
#       {'fabrics:TpID': 'sw1p3s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f7',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '147'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s4'}]},
#       {'fabrics:TpID': 'sw1p22s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:43',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '43'}},
#       {'fabrics:TpID': 'sw1p2s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f0',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '136'}},
#       {'fabrics:TpID': 'sw1p29s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:5d',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '149'}},
#       {'fabrics:TpID': 'sw1p6s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:01',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '169'}},
#       {'fabrics:TpID': 'sw1p11s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:15',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '45'}},
#       {'fabrics:TpID': 'sw1p28s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:58',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '164'}},
#       {'fabrics:TpID': 'sw1p20s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:38',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '24'}},
#       {'fabrics:TpID': 'sw1p13s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:1c',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '28'}},
#       {'fabrics:TpID': 'sw1p5s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:fe',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '162'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccd2'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s3'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'}]},
#       {'fabrics:TpID': 'sw1p9s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:0f',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '63'}},
#       {'fabrics:TpID': 'sw1p7s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:07',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '179'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccd2'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s4'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'}]},
#       {'fabrics:TpID': 'sw1p1s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:ed',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '129'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s2'}]},
#       {'fabrics:TpID': 'sw1p3s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f6',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '146'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s3'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
#          'fabrics:Value': 'Ethernet Port'},
#         {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#         {'fabrics:TheKey': 'LLDP:SystemDescription',
#          'fabrics:Value': 'spine node (fabric:123)'},
#         {'fabrics:TheKey': 'LLDP:ChassisID',
#          'fabrics:Value': '0x0090fb64ccfd'}]},
#       {'fabrics:TpID': 'sw1p31s3',
#        'fabrics:Name': 'LF3-31-3:ZT_GATE-2-1',
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'USER_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:66',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '134'},
#         {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#          'fabrics:Value': '6c:b3:11:20:e8:54'},
#         {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#          'fabrics:Value': '6c:b3:11:20:e8:54'}]},
#       {'fabrics:TpID': 'sw1p22s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:40',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '40'}},
#       {'fabrics:TpID': 'sw1p17s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:2d',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '1'}},
#       {'fabrics:TpID': 'sw1p23s2',
#        'fabrics:Name': 'LF-3-23-2:APP2-1',
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'USER_PORT',
#        'fabrics:Bandwidth': '10G',
#        'fabrics:BandwidthState': '10G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'NONE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:45',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '49'}},
#       {'fabrics:TpID': 'sw1p16s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:2a',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '6'}},
#       {'fabrics:TpID': 'sw1p30s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:63',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '159'}},
#       {'fabrics:TpID': 'sw1p18s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:31',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '9'}},
#       {'fabrics:TpID': 'sw1p16s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:28',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '4'}},
#       {'fabrics:TpID': 'sw1p15s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:26',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '14'}},
#       {'fabrics:TpID': 'sw1p17s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:2f',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '3'}},
#       {'fabrics:TpID': 'sw1p12s4',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:1b',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '39'}},
#       {'fabrics:TpID': 'sw1p23s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:46',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '50'}},
#       {'fabrics:TpID': 'sw1p11s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:16',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '46'}},
#       {'fabrics:TpID': 'sw1p4s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:fa',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '154'}},
#       {'fabrics:TpID': 'sw1p2s2',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:f1',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '137'}},
#       {'fabrics:TpID': 'sw1p12s3',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'DOWN',
#        'fabrics:AssignmentState': 'UNALLOCATED',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['25G', '10G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:26:1a',
#        'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '38'}},
#       {'fabrics:TpID': 'sw1p5s1',
#        'fabrics:Name': None,
#        'fabrics:Type': 'L1_INTERFACE',
#        'fabrics:AdminState': 'UP',
#        'fabrics:OperState': 'UP',
#        'fabrics:AssignmentState': 'FABRIC_PORT',
#        'fabrics:Bandwidth': '25G',
#        'fabrics:BandwidthState': '25G',
#        'fabrics:BandwidthOption': ['10G', '25G'],
#        'fabrics:FecType': 'FIRE-CODE',
#        'fabrics:EnableFec': 'true',
#        'fabrics:PhysAddress': 'b8:6a:97:96:25:fc',
#        'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#          'fabrics:Value': '160'},
#         {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s1'},
#         {'fabrics:TheKey': 'LLDP:PortDescription',
# ...
#      'fabrics:DestNode': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#      'fabrics:DestTp': 'sw1p13s4'},
#     {'fabrics:LinkID': '11048',
#      'fabrics:SourceNode': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#      'fabrics:SourceTp': 'sw1p13s4',
#      'fabrics:DestNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:DestTp': 'sw1p5s4'},
#     {'fabrics:LinkID': '11049',
#      'fabrics:SourceNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SourceTp': 'sw1p3s2',
#      'fabrics:DestNode': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#      'fabrics:DestTp': 'sw1p15s2'},
#     {'fabrics:LinkID': '11050',
#      'fabrics:SourceNode': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#      'fabrics:SourceTp': 'sw1p15s2',
#      'fabrics:DestNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:DestTp': 'sw1p3s2'}],
#    'fabrics:Slice': [{'fabrics:SliceID': '1',
#      'fabrics:TpMapping': [{'fabrics:TpID': '38635c81-0c0e-490a-8d6e-25bceee93f70',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p31s4'},
#       {'fabrics:TpID': '4524dc5c-1e37-48c2-a596-0ba2abb7ff19',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p29s3'},
#       {'fabrics:TpID': '6302efb9-3925-4e94-873a-547f988c27d3',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p31s1'},
#       {'fabrics:TpID': '151538ec-01a1-410e-88d6-3ef7a1cf68ef',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p31s2'},
#       {'fabrics:TpID': 'c42e71ce-9ab3-4bfc-a8f2-a82a36450cc9',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p21s2'},
#       {'fabrics:TpID': '4f84e507-5da5-4865-8daf-f12045b3cb04',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p31s1'},
#       {'fabrics:TpID': 'af2fdf3f-3d34-4768-b19b-3730aa134942',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p31s3'},
#       {'fabrics:TpID': 'ec1f138f-87ce-49c1-9a86-4a92e240245b',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p31s3'},
#       {'fabrics:TpID': '323e6242-b988-401b-a44a-11bd1374a9f8',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p21s1'},
#       {'fabrics:TpID': '9dfc3542-d6a0-4114-9313-3f2589f2e2a9',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p21s3'},
#       {'fabrics:TpID': '6893b948-5f79-47dc-a015-c912f2431b8a',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p21s4'},
#       {'fabrics:TpID': '757c8f40-95be-4974-9be7-3f8801d04512',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p31s2'}]},
#     {'fabrics:SliceID': '2',
#      'fabrics:TpMapping': [{'fabrics:TpID': '4c09890e-3343-489c-ab78-708f1869ce44',
#        'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#        'fabrics:TpRef': 'sw1p31s3'},
#       {'fabrics:TpID': '61c62b1e-562e-40d7-b502-27913ca4064d',
#        'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#        'fabrics:TpRef': 'sw1p31s4'},
#       {'fabrics:TpID': '16741fae-8431-431f-bbaf-cd42ebd9b215',
#        'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#        'fabrics:TpRef': 'sw1p31s1'},
#       {'fabrics:TpID': '95f7435c-edcc-46d2-81d1-b90c5abb6273',
#        'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#        'fabrics:TpRef': 'sw1p31s2'},
#       {'fabrics:TpID': 'ba26ede3-3ae6-4514-9641-45294938c499',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p29s2'},
#       {'fabrics:TpID': '00f7e862-ff94-408f-9013-93d539fa16bc',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p23s2'},
#       {'fabrics:TpID': '7abaeb04-4e49-4f76-b503-46c4c5351983',
#        'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#        'fabrics:TpRef': 'sw1p23s2'}]},
#     {'fabrics:SliceID': '3',
#      'fabrics:TpMapping': [{'fabrics:TpID': '1a9cceca-abc7-4b5d-b144-1f73daaaf339',
#        'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#        'fabrics:TpRef': 'sw1p31s1'},
#       {'fabrics:TpID': '267a8633-57c2-4220-8de2-4be3f80da043',
#        'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#        'fabrics:TpRef': 'sw1p31s2'},
#       {'fabrics:TpID': '3ccd5d78-ca51-49ba-b6cb-ca79c6940d62',
#        'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#        'fabrics:TpRef': 'sw1p31s3'},
#       {'fabrics:TpID': 'a7b71b54-89bd-4c76-9072-0f021638c79a',
#        'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#        'fabrics:TpRef': 'sw1p31s4'},
#       {'fabrics:TpID': '45013883-fb74-4db1-9756-d3a6c3eda778',
#        'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#        'fabrics:TpRef': 'sw1p29s1'}]},
#     {'fabrics:SliceID': '65535',
#      'fabrics:TpMapping': {'fabrics:TpID': 'b8bf39c3-805f-449e-984e-a9b8349b1e9f',
#       'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:TpRef': 'sw1p25s4'}}],
#    'fabrics:DNSServer': [{'fabrics:IPAddr': '10.0.30.146'},
#     {'fabrics:IPAddr': 'fd50:f:a:b::146'}],
#    'fabrics:NtpServer': [{'fabrics:IpAddr': '10.0.30.146',
#      'fabrics:MinPoll': '6',
#      'fabrics:MaxPoll': '10'},
#     {'fabrics:IpAddr': 'fd50:f:a:b::146',
#      'fabrics:MinPoll': '6',
#      'fabrics:MaxPoll': '10'}]},
#   'fabrics:VirtualFabric': [{'fabrics:VFabricID': '65535',
#     'fabrics:Name': 'DCIP_VirtualFabric',
#     'fabrics:Status': 'CREATED',
#     'fabrics:ManagementIPv4Address': '10.0.20.151',
#     'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::3',
#     'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#      'fabrics:Status': 'running',
#      'fabrics:IPv4Address': '10.0.20.157',
#      'fabrics:IPv6Address': '2602:807:900e:1d2::9'},
#     'fabrics:VirtualTerminationPoint': {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '65535',
#      'fabrics:TpRef': 'b8bf39c3-805f-449e-984e-a9b8349b1e9f',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#      'fabrics:SupportingTpRef': 'sw1p25s4',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}},
#    {'fabrics:VFabricID': '1',
#     'fabrics:Name': 'ZeroTrust',
#     'fabrics:Status': 'CREATED',
#     'fabrics:ManagementIPv4Address': '10.0.20.158',
#     'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::a',
#     'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#      'fabrics:Status': 'stopped',
#      'fabrics:IPv4Address': '10.0.20.159',
#      'fabrics:IPv6Address': '2602:807:900e:1d2::b'},
#     'fabrics:VirtualTerminationPoint': [{'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '38635c81-0c0e-490a-8d6e-25bceee93f70',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p31s4',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '4524dc5c-1e37-48c2-a596-0ba2abb7ff19',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p29s3',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '6302efb9-3925-4e94-873a-547f988c27d3',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p31s1',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '151538ec-01a1-410e-88d6-3ef7a1cf68ef',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p31s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': 'c42e71ce-9ab3-4bfc-a8f2-a82a36450cc9',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p21s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '4f84e507-5da5-4865-8daf-f12045b3cb04',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p31s1',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': 'af2fdf3f-3d34-4768-b19b-3730aa134942',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p31s3',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': 'ec1f138f-87ce-49c1-9a86-4a92e240245b',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p31s3',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '323e6242-b988-401b-a44a-11bd1374a9f8',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p21s1',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '9dfc3542-d6a0-4114-9313-3f2589f2e2a9',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p21s3',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '6893b948-5f79-47dc-a015-c912f2431b8a',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p21s4',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '1',
#       'fabrics:TpRef': '757c8f40-95be-4974-9be7-3f8801d04512',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p31s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}]},
#    {'fabrics:VFabricID': '2',
#     'fabrics:Name': 'OpenStack_NET53',
#     'fabrics:Status': 'CREATED',
#     'fabrics:ManagementIPv4Address': '10.0.20.160',
#     'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::c',
#     'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#      'fabrics:Status': 'running',
#      'fabrics:IPv4Address': '10.0.20.161',
#      'fabrics:IPv6Address': '2602:807:900e:1d2::d'},
#     'fabrics:VirtualTerminationPoint': [{'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': '4c09890e-3343-489c-ab78-708f1869ce44',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:SupportingTpRef': 'sw1p31s3',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': '61c62b1e-562e-40d7-b502-27913ca4064d',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:SupportingTpRef': 'sw1p31s4',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': '16741fae-8431-431f-bbaf-cd42ebd9b215',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:SupportingTpRef': 'sw1p31s1',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': '95f7435c-edcc-46d2-81d1-b90c5abb6273',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:SupportingTpRef': 'sw1p31s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': 'ba26ede3-3ae6-4514-9641-45294938c499',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p29s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': '00f7e862-ff94-408f-9013-93d539fa16bc',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p23s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '2',
#       'fabrics:TpRef': '7abaeb04-4e49-4f76-b503-46c4c5351983',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:SupportingTpRef': 'sw1p23s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}]},
#    {'fabrics:VFabricID': '3',
#     'fabrics:Name': 'OpenStack_NET52',
#     'fabrics:Status': 'CREATED',
#     'fabrics:ManagementIPv4Address': '10.0.20.162',
#     'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::e',
#     'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#      'fabrics:Status': 'running',
#      'fabrics:IPv4Address': '10.0.20.163',
#      'fabrics:IPv6Address': '2602:807:900e:1d2::f'},
#     'fabrics:VirtualTerminationPoint': [{'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '3',
#       'fabrics:TpRef': '1a9cceca-abc7-4b5d-b144-1f73daaaf339',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:SupportingTpRef': 'sw1p31s1',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '3',
#       'fabrics:TpRef': '267a8633-57c2-4220-8de2-4be3f80da043',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:SupportingTpRef': 'sw1p31s2',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '3',
#       'fabrics:TpRef': '3ccd5d78-ca51-49ba-b6cb-ca79c6940d62',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:SupportingTpRef': 'sw1p31s3',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '3',
#       'fabrics:TpRef': 'a7b71b54-89bd-4c76-9072-0f021638c79a',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:SupportingTpRef': 'sw1p31s4',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#      {'fabrics:FabricRef': '123',
#       'fabrics:NodeRef': '3',
#       'fabrics:TpRef': '45013883-fb74-4db1-9756-d3a6c3eda778',
#       'fabrics:SupportingFabricRef': '123',
#       'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:SupportingTpRef': 'sw1p29s1',
#       'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}]}]}}

# %%
rpc="""
<get><filter type="subtree"><top xmlns="urn:kaloom:faas:fabrics"/><Fabric><FabricID>123
</FabricID><Node><Role></Role><TerminationPoint><OperState>UP</OperState></TerminationPoint></Node></Fabric></filter></get>""" 
kaloom_netconf_rpc(rpc)['data']['top']['fabrics:Fabric']
# Out:
# {'fabrics:FabricID': '123',
#  'fabrics:Node': [{'fabrics:NodeID': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#    'fabrics:Role': 'LEAF',
#    'fabrics:TerminationPoint': [{'fabrics:TpID': 'sw1p1s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:ee',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '130'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'}]},
#     {'fabrics:TpID': 'sw1p3s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:f5',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '145'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID',
#        'fabrics:Value': '0x0090fb64ccfd'}]},
#     {'fabrics:TpID': 'sw1p7s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:05',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '177'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'}]},
#     {'fabrics:TpID': 'sw1p3s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:f4',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '144'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p21s1',
#      'fabrics:Name': 'LF3-21-1:ESXi1-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:3c',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '32'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '3c:fd:fe:b9:f6:64'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '3c:fd:fe:b9:f6:64'}]},
#     {'fabrics:TpID': 'sw1p1s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:ec',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '128'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p21s2',
#      'fabrics:Name': 'LF3-21-2:ESXi2-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:3d',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '33'}},
#     {'fabrics:TpID': 'sw1p3s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:f7',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '147'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s4'}]},
#     {'fabrics:TpID': 'sw1p5s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:fe',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '162'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p7s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:07',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '179'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p1s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:ed',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '129'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s2'}]},
#     {'fabrics:TpID': 'sw1p3s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:f6',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '146'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID',
#        'fabrics:Value': '0x0090fb64ccfd'}]},
#     {'fabrics:TpID': 'sw1p31s3',
#      'fabrics:Name': 'LF3-31-3:ZT_GATE-2-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:66',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '134'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '6c:b3:11:20:e8:54'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '6c:b3:11:20:e8:54'}]},
#     {'fabrics:TpID': 'sw1p23s2',
#      'fabrics:Name': 'LF-3-23-2:APP2-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:45',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '49'}},
#     {'fabrics:TpID': 'sw1p5s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:fc',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '160'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID',
#        'fabrics:Value': '0x0090fb64ccd2'}]},
#     {'fabrics:TpID': 'sw1p7s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:06',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '178'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p5s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:fd',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '161'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p21s3',
#      'fabrics:Name': 'LF3-21-3:ESXi3-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:3e',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '34'}},
#     {'fabrics:TpID': 'sw1p5s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:ff',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '163'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p31s2',
#      'fabrics:Name': 'LF3-31-2:ZT_GATE-1-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:65',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '133'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '3c:fd:fe:b9:f4:40'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '3c:fd:fe:b9:f4:40'}]},
#     {'fabrics:TpID': 'sw1p7s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:04',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '176'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p1s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:25:ef',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '131'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p21s4',
#      'fabrics:Name': 'LF3-21-4:ESXi4-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:3f',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '35'}},
#     {'fabrics:TpID': 'sw1p31s1',
#      'fabrics:Name': 'LF3-31-1:ZT_CON-1-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:26:64',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '132'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '3c:fd:fe:b9:f7:70'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '3c:fd:fe:b9:f7:70'}]}]},
#   {'fabrics:NodeID': 'a406445a-a733-4488-9089-53b7d69c8191',
#    'fabrics:Role': 'LEAF',
#    'fabrics:TerminationPoint': [{'fabrics:TpID': 'sw1p7s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:8a',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '178'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p7s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:88',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '176'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s1'}]},
#     {'fabrics:TpID': 'sw1p1s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:72',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '130'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'}]},
#     {'fabrics:TpID': 'sw1p3s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:79',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '145'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p31s4',
#      'fabrics:Name': 'LF-1-31-4:OS-4',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:eb',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '135'}},
#     {'fabrics:TpID': 'sw1p5s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:80',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '160'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p1s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:71',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '129'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s2'}]},
#     {'fabrics:TpID': 'sw1p31s2',
#      'fabrics:Name': 'LF-1-31-2:OS-2',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:e9',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '133'}},
#     {'fabrics:TpID': 'sw1p31s1',
#      'fabrics:Name': 'LF-1-31-1:OS-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:e8',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '132'}},
#     {'fabrics:TpID': 'sw1p25s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:d2',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '190'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'controller-3'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'controller node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x44a8423546a0'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'kvsenp4s0f0'}]},
#     {'fabrics:TpID': 'sw1p25s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:d1',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '189'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x549f3525a330'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'kvsenp4s0f0'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'controller-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'controller node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p1s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:73',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '131'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p25s4',
#      'fabrics:Name': 'LF-1-25-4:COL-1',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:d3',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '191'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '6c:b3:11:20:e8:7c'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '6c:b3:11:20:e8:7c'}]},
#     {'fabrics:TpID': 'sw1p1s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:70',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '128'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p5s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:81',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '161'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'}]},
#     {'fabrics:TpID': 'sw1p3s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:7a',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '146'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s3'}]},
#     {'fabrics:TpID': 'sw1p3s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:7b',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '147'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s4'}]},
#     {'fabrics:TpID': 'sw1p5s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:83',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '163'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p7s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:89',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '177'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p31s3',
#      'fabrics:Name': 'LF-1-31-3:OS-3',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:ea',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '134'}},
#     {'fabrics:TpID': 'sw1p25s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:d0',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '188'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'controller-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'controller node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x44a8421eb085'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'kvsenp4s0f0'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p3s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:78',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '144'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p7s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:8b',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '179'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p3s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'}]},
#     {'fabrics:TpID': 'sw1p5s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:1a:82',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '162'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p1s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'}]}]},
#   {'fabrics:NodeID': '9e4d42ac-714d-4d98-ba40-d12a40a0ffc7',
#    'fabrics:Role': 'CONTROLLER',
#    'fabrics:TerminationPoint': [{'fabrics:TpID': 'kvsenp4s0f0',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'false',
#      'fabrics:PhysAddress': '66:e1:9a:65:f6:33',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '2'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccc4'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p25s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'leaf-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'leaf node (fabric:123)'}]},
#     {'fabrics:TpID': 'kvsenp4s0f1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'false',
#      'fabrics:PhysAddress': '7e:aa:f6:cb:c4:2a',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '4'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd4'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p25s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'leaf-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'leaf node (fabric:123)'}]}]},
#   {'fabrics:NodeID': 'f9d471b0-6716-4f00-82be-0d8afd5f8492',
#    'fabrics:Role': 'CONTROLLER',
#    'fabrics:TerminationPoint': [{'fabrics:TpID': 'kvsenp4s0f1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'false',
#      'fabrics:PhysAddress': '92:ca:f1:d4:40:8f',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'leaf-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'leaf node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd4'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p25s3'}]},
#     {'fabrics:TpID': 'kvsenp4s0f0',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'false',
#      'fabrics:PhysAddress': '1a:a0:f1:c8:a6:ca',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'leaf node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccc4'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p25s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'leaf-1'}]}]},
#   {'fabrics:NodeID': 'b9b46f83-6e9e-4e71-887d-7bbe230ba902',
#    'fabrics:Role': 'CONTROLLER',
#    'fabrics:TerminationPoint': [{'fabrics:TpID': 'kvsenp4s0f1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'false',
#      'fabrics:PhysAddress': '62:eb:b3:d9:b2:4e',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '4'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'leaf node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd4'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p25s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'leaf-2'}]},
#     {'fabrics:TpID': 'kvsenp4s0f0',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'false',
#      'fabrics:PhysAddress': '7a:ad:1e:4d:b3:14',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p25s2'},
# ...
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '181'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s2'}]},
#     {'fabrics:TpID': 'sw1p29s3',
#      'fabrics:Name': 'LF-4-29-3:WG-3',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:8e',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '146'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID', 'fabrics:Value': 'te-1/1/3'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortDescription',
#        'fabrics:Value': 'te-1/1/3'},
#       {'fabrics:TheKey': 'LLDP-vDCO:SystemName', 'fabrics:Value': 'WG-01'},
#       {'fabrics:TheKey': 'LLDP-vDCO:SystemDescription',
#        'fabrics:Value': 'Pica8, Inc.,AS4630-54PE, PICOS 4.2.2.2'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '90:3c:b3:2c:af:69'}]},
#     {'fabrics:TpID': 'sw1p1s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:1e',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '134'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p13s3'}]},
#     {'fabrics:TpID': 'sw1p5s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:2e',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '166'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p13s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p3s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:24',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '148'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p5s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:2c',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '164'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p13s1'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p29s2',
#      'fabrics:Name': 'LF-4-29-2:WG-2',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:8d',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '145'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '90:3c:b3:2c:af:69'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID', 'fabrics:Value': 'te-1/1/2'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortDescription',
#        'fabrics:Value': 'te-1/1/2'},
#       {'fabrics:TheKey': 'LLDP-vDCO:SystemName', 'fabrics:Value': 'WG-01'},
#       {'fabrics:TheKey': 'LLDP-vDCO:SystemDescription',
#        'fabrics:Value': 'Pica8, Inc.,AS4630-54PE, PICOS 4.2.2.2'}]},
#     {'fabrics:TpID': 'sw1p7s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:37',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '183'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID',
#        'fabrics:Value': '0x0090fb64ccd2'}]},
#     {'fabrics:TpID': 'sw1p7s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:36',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '182'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s3'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID',
#        'fabrics:Value': '0x0090fb64ccd2'}]},
#     {'fabrics:TpID': 'sw1p1s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:1d',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '133'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p13s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p23s2',
#      'fabrics:Name': 'LF-4-23-2:APP2-2',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '10G',
#      'fabrics:BandwidthState': '10G',
#      'fabrics:BandwidthOption': ['10G', '25G'],
#      'fabrics:FecType': 'NONE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:75',
#      'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#       'fabrics:Value': '53'}},
#     {'fabrics:TpID': 'sw1p31s1',
#      'fabrics:Name': 'LF4-31-1:CON-1-2',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:94',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '128'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '3c:fd:fe:b9:f7:71'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '3c:fd:fe:b9:f7:71'}]},
#     {'fabrics:TpID': 'sw1p31s2',
#      'fabrics:Name': 'LF4-31-2:ZT_GATE-1-2',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:95',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '129'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '3c:fd:fe:b9:f4:41'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '3c:fd:fe:b9:f4:41'}]},
#     {'fabrics:TpID': 'sw1p1s1',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:1c',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '132'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p13s1'}]},
#     {'fabrics:TpID': 'sw1p3s3',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:26',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '150'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s3'}]},
#     {'fabrics:TpID': 'sw1p3s4',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:27',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '151'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s4'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'}]},
#     {'fabrics:TpID': 'sw1p3s2',
#      'fabrics:Name': None,
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'FABRIC_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:25',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '149'},
#       {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#       {'fabrics:TheKey': 'LLDP:SystemDescription',
#        'fabrics:Value': 'spine node (fabric:123)'},
#       {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#       {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p15s2'},
#       {'fabrics:TheKey': 'LLDP:PortDescription',
#        'fabrics:Value': 'Ethernet Port'}]},
#     {'fabrics:TpID': 'sw1p31s3',
#      'fabrics:Name': 'LF4-31-3:ZT_GATE-2-2',
#      'fabrics:Type': 'L1_INTERFACE',
#      'fabrics:AdminState': 'UP',
#      'fabrics:OperState': 'UP',
#      'fabrics:AssignmentState': 'USER_PORT',
#      'fabrics:Bandwidth': '25G',
#      'fabrics:BandwidthState': '25G',
#      'fabrics:BandwidthOption': ['25G', '10G'],
#      'fabrics:FecType': 'FIRE-CODE',
#      'fabrics:EnableFec': 'true',
#      'fabrics:PhysAddress': 'b8:6a:97:96:28:96',
#      'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '130'},
#       {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#        'fabrics:Value': '6c:b3:11:20:e8:56'},
#       {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#        'fabrics:Value': '6c:b3:11:20:e8:56'}]}]}]}
