# %%
from ncclient import manager
import json
import xmltodict,json

# %%
host = "10.0.20.150"
user = "admin"
pwd = "Forwiz_SDF1"

rpc = '<get></get>'
with manager.connect(host=host, port=830, username=user, password=pwd, hostkey_verify=False) as m:
    c = m.get().xml

# %%
res_dict=xmltodict.parse(a)

# %%
res_dict['rpc-reply']['data']
# Out:
# {'@xmlns:fabrics': 'urn:kaloom:faas:fabrics',
#  '@xmlns:pa': 'urn:kaloom:faas:port-attributes',
#  'fabrics:telemetry-system': {'fabrics:enabled': 'true',
#   'fabrics:collector': {'fabrics:address': '192.168.40.60',
#    'fabrics:port': '4171',
#    'fabrics:next-hop-mac-address': '52:93:8e:e6:96:e0'},
#   'fabrics:flow': [{'fabrics:name': 'POSTECH_INT',
#     'fabrics:priority': '1',
#     'fabrics:destination-address-prefix': '192.168.53.107/32',
#     'fabrics:exclude-filter': 'false',
#     'fabrics:sample-percentage': '100'},
#    {'fabrics:name': 'ICMP_TEST',
#     'fabrics:priority': '3',
#     'fabrics:destination-address-prefix': '0.0.0.0/0',
#     'fabrics:protocol': '1',
#     'fabrics:exclude-filter': 'false',
#     'fabrics:sample-percentage': '100'},
#    {'fabrics:name': 'INT_TEST',
#     'fabrics:priority': '2',
#     'fabrics:destination-address-prefix': '0.0.0.0/0',
#     'fabrics:exclude-filter': 'false',
#     'fabrics:sample-percentage': '0'}]},
#  'fabrics:Fabric': {'fabrics:FabricID': '123',
#   'fabrics:Hostname': None,
#   'fabrics:Name': 'Fabric-123',
#   'fabrics:Description': None,
#   'fabrics:Timezone': 'America/Montreal',
#   'fabrics:Quorum': '3',
#   'fabrics:NbControllers': '3',
#   'fabrics:EnableGUI': 'true',
#   'fabrics:TopologyOperStatus': {'fabrics:TopologyClass': 'InvalidTopology',
#    'fabrics:Valid': 'false',
#    'fabrics:ValidityCount': '4',
#    'fabrics:Error': 'UnevenLinkCardinality'},
#   'fabrics:OutOfBandManagementNetwork': {'fabrics:InterfaceName': 'netd10af457daa1',
#    'fabrics:VlanID': '20',
#    'fabrics:IPv4': {'fabrics:NetworkPrefix': '10.0.20.0/24',
#     'fabrics:LowerAddress': '10.0.20.150',
#     'fabrics:UpperAddress': '10.0.20.170',
#     'fabrics:Gateway': '10.0.20.254',
#     'fabrics:ManagementAddress': '10.0.20.150',
#     'fabrics:GUIAddress': '10.0.20.156'},
#    'fabrics:IPv6': {'fabrics:NetworkPrefix': '2602:807:900e:1d2::/64',
#     'fabrics:LowerAddress': '2602:807:900e:1d2::1',
#     'fabrics:UpperAddress': '2602:807:900e:1d2:ffff:ffff:ffff:ffff',
#     'fabrics:Gateway': '2602:807:900e:1d2::1',
#     'fabrics:ManagementAddress': '2602:807:900e:1d2::2',
#     'fabrics:GUIAddress': '2602:807:900e:1d2::8'}},
#   'fabrics:Node': [{'fabrics:NodeID': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#     'fabrics:Hostname': 'leaf-3',
#     'fabrics:Name': 'leaf-3',
#     'fabrics:Description': None,
#     'fabrics:DeviceID': '622692977828',
#     'fabrics:DeviceMAC': '00:90:fb:64:cc:a4',
#     'fabrics:Role': 'LEAF',
#     'fabrics:MACAddressBase': 'b8:6a:97:96:25:ec',
#     'fabrics:MACAddressCount': '132',
#     'fabrics:AdminState': 'UP',
#     'fabrics:OperState': 'UP',
#     'fabrics:System': {'fabrics:SystemUptime': '08:10:37 up 14 days,  5:30,  0 users,  load average: 3.85, 3.43, 3.26',
#      'fabrics:SystemClock': 'Mon Oct 31 08:10:37 UTC 2022',
#      'fabrics:SystemMemory': {'fabrics:MemTotal': '8043648',
#       'fabrics:MemFree': '79328',
#       'fabrics:Cached': '4452992',
#       'fabrics:SwapCached': '0',
#       'fabrics:SwapTotal': '0',
#       'fabrics:SwapFree': '0'}},
#     'fabrics:Hardware': {'fabrics:Polling': {'fabrics:Interval': '30'}},
#     'fabrics:TerminationPoint': [{'fabrics:TpID': 'sw1p29s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:5e',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '150'}},
#      {'fabrics:TpID': 'sw1p14s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:22',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '22'}},
#      {'fabrics:TpID': 'sw1p29s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:5c',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '148'}},
#      {'fabrics:TpID': 'sw1p13s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:1d',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '29'}},
#      {'fabrics:TpID': 'sw1p24s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:4a',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '58'}},
#      {'fabrics:TpID': 'sw1p28s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:5a',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '166'}},
#      {'fabrics:TpID': 'sw1p2s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f3',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '139'}},
#      {'fabrics:TpID': 'sw1p1s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:ee',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '130'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s3'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'}]},
#      {'fabrics:TpID': 'sw1p18s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:32',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '10'}},
#      {'fabrics:TpID': 'sw1p14s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:21',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '21'}},
#      {'fabrics:TpID': 'sw1p4s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f8',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '152'}},
#      {'fabrics:TpID': 'sw1p3s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f5',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '145'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s2'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID',
#         'fabrics:Value': '0x0090fb64ccfd'}]},
#      {'fabrics:TpID': 'sw1p7s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:05',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '177'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s2'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'}]},
#      {'fabrics:TpID': 'sw1p31s4',
#       'fabrics:Name': 'LF3-31-4:ZT_ESXi5-1',
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'USER_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:67',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '135'}},
#      {'fabrics:TpID': 'sw1p4s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f9',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '153'}},
#      {'fabrics:TpID': 'sw1p3s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f4',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '144'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s1'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'}]},
#      {'fabrics:TpID': 'sw1p8s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:0b',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '187'}},
#      {'fabrics:TpID': 'sw1p21s1',
#       'fabrics:Name': 'LF3-21-1:ESXi1-1',
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'USER_PORT',
#       'fabrics:Bandwidth': '10G',
#       'fabrics:BandwidthState': '10G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'NONE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:3c',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '32'},
#        {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#         'fabrics:Value': '3c:fd:fe:b9:f6:64'},
#        {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#         'fabrics:Value': '3c:fd:fe:b9:f6:64'}]},
#      {'fabrics:TpID': 'sw1p16s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:29',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '5'}},
#      {'fabrics:TpID': 'sw1p32s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:6b',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '143'}},
#      {'fabrics:TpID': 'sw1p26s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:52',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '182'}},
#      {'fabrics:TpID': 'sw1p10s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:13',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '55'}},
#      {'fabrics:TpID': 'sw1p1s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:ec',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '128'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s1'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'}]},
#      {'fabrics:TpID': 'sw1p20s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:3b',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '27'}},
#      {'fabrics:TpID': 'sw1p14s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:23',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '23'}},
#      {'fabrics:TpID': 'sw1p27s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:57',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '175'}},
#      {'fabrics:TpID': 'sw1p12s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:18',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '36'}},
#      {'fabrics:TpID': 'sw1p22s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:42',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '42'}},
#      {'fabrics:TpID': 'sw1p24s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:48',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '56'}},
#      {'fabrics:TpID': 'sw1p11s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:14',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '44'}},
#      {'fabrics:TpID': 'sw1p25s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:4f',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '191'}},
#      {'fabrics:TpID': 'sw1p10s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:10',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '52'}},
#      {'fabrics:TpID': 'sw1p30s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:60',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '156'}},
#      {'fabrics:TpID': 'sw1p32s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:6a',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '142'}},
#      {'fabrics:TpID': 'sw1p24s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:49',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '57'}},
#      {'fabrics:TpID': 'sw1p6s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:02',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '170'}},
#      {'fabrics:TpID': 'sw1p8s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:09',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '185'}},
#      {'fabrics:TpID': 'sw1p21s2',
#       'fabrics:Name': 'LF3-21-2:ESXi2-1',
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'USER_PORT',
#       'fabrics:Bandwidth': '10G',
#       'fabrics:BandwidthState': '10G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'NONE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:3d',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '33'}},
#      {'fabrics:TpID': 'sw1p3s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f7',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '147'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s4'}]},
#      {'fabrics:TpID': 'sw1p22s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:43',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '43'}},
#      {'fabrics:TpID': 'sw1p2s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f0',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '136'}},
#      {'fabrics:TpID': 'sw1p29s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:5d',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '149'}},
#      {'fabrics:TpID': 'sw1p6s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:01',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '169'}},
#      {'fabrics:TpID': 'sw1p11s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:15',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '45'}},
#      {'fabrics:TpID': 'sw1p28s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:58',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '164'}},
#      {'fabrics:TpID': 'sw1p20s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:38',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '24'}},
#      {'fabrics:TpID': 'sw1p13s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:1c',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '28'}},
#      {'fabrics:TpID': 'sw1p5s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:fe',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '162'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s3'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'}]},
#      {'fabrics:TpID': 'sw1p9s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:0f',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '63'}},
#      {'fabrics:TpID': 'sw1p7s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:07',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '179'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccd2'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s4'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'}]},
#      {'fabrics:TpID': 'sw1p1s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:ed',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '129'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID', 'fabrics:Value': '0x0090fb64ccfd'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s2'}]},
#      {'fabrics:TpID': 'sw1p3s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f6',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '146'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p11s3'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-1'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID',
#         'fabrics:Value': '0x0090fb64ccfd'}]},
#      {'fabrics:TpID': 'sw1p31s3',
#       'fabrics:Name': 'LF3-31-3:ZT_GATE-2-1',
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'USER_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:66',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '134'},
#        {'fabrics:TheKey': 'LLDP-vDCO:PortID',
#         'fabrics:Value': '6c:b3:11:20:e8:54'},
#        {'fabrics:TheKey': 'LLDP-vDCO:ChassisID',
#         'fabrics:Value': '6c:b3:11:20:e8:54'}]},
#      {'fabrics:TpID': 'sw1p22s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:40',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '40'}},
#      {'fabrics:TpID': 'sw1p17s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:2d',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '1'}},
#      {'fabrics:TpID': 'sw1p23s2',
#       'fabrics:Name': 'LF-3-23-2:APP2-1',
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'USER_PORT',
#       'fabrics:Bandwidth': '10G',
#       'fabrics:BandwidthState': '10G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'NONE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:45',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '49'}},
#      {'fabrics:TpID': 'sw1p16s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:2a',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '6'}},
#      {'fabrics:TpID': 'sw1p30s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:63',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '159'}},
#      {'fabrics:TpID': 'sw1p18s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:31',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '9'}},
#      {'fabrics:TpID': 'sw1p16s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:28',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '4'}},
#      {'fabrics:TpID': 'sw1p15s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:26',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '14'}},
#      {'fabrics:TpID': 'sw1p17s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:2f',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '3'}},
#      {'fabrics:TpID': 'sw1p12s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:1b',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '39'}},
#      {'fabrics:TpID': 'sw1p23s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:46',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '50'}},
#      {'fabrics:TpID': 'sw1p11s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:16',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '46'}},
#      {'fabrics:TpID': 'sw1p4s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:fa',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '154'}},
#      {'fabrics:TpID': 'sw1p2s2',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:f1',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '137'}},
#      {'fabrics:TpID': 'sw1p12s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:1a',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '38'}},
#      {'fabrics:TpID': 'sw1p5s1',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:25:fc',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
#         'fabrics:Value': '160'},
#        {'fabrics:TheKey': 'LLDP:PortID', 'fabrics:Value': 'sw1p9s1'},
#        {'fabrics:TheKey': 'LLDP:PortDescription',
#         'fabrics:Value': 'Ethernet Port'},
#        {'fabrics:TheKey': 'LLDP:SystemName', 'fabrics:Value': 'spine-2'},
#        {'fabrics:TheKey': 'LLDP:SystemDescription',
#         'fabrics:Value': 'spine node (fabric:123)'},
#        {'fabrics:TheKey': 'LLDP:ChassisID',
#         'fabrics:Value': '0x0090fb64ccd2'}]},
#      {'fabrics:TpID': 'sw1p6s4',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'DOWN',
#       'fabrics:AssignmentState': 'UNALLOCATED',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['25G', '10G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:03',
#       'fabrics:TPAnnotations': {'fabrics:TheKey': 'SDF:HwPortNum',
#        'fabrics:Value': '171'}},
#      {'fabrics:TpID': 'sw1p7s3',
#       'fabrics:Name': None,
#       'fabrics:Type': 'L1_INTERFACE',
#       'fabrics:AdminState': 'UP',
#       'fabrics:OperState': 'UP',
#       'fabrics:AssignmentState': 'FABRIC_PORT',
#       'fabrics:Bandwidth': '25G',
#       'fabrics:BandwidthState': '25G',
#       'fabrics:BandwidthOption': ['10G', '25G'],
#       'fabrics:FecType': 'FIRE-CODE',
#       'fabrics:EnableFec': 'true',
#       'fabrics:PhysAddress': 'b8:6a:97:96:26:06',
#       'fabrics:TPAnnotations': [{'fabrics:TheKey': 'SDF:HwPortNum',
# ...
#     'fabrics:SourceTp': 'sw1p13s1',
#     'fabrics:DestNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#     'fabrics:DestTp': 'sw1p5s1'},
#    {'fabrics:LinkID': '11047',
#     'fabrics:SourceNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#     'fabrics:SourceTp': 'sw1p5s4',
#     'fabrics:DestNode': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#     'fabrics:DestTp': 'sw1p13s4'},
#    {'fabrics:LinkID': '11048',
#     'fabrics:SourceNode': '4951c52c-465c-43a6-9b5b-91d11479bbe9',
#     'fabrics:SourceTp': 'sw1p13s4',
#     'fabrics:DestNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#     'fabrics:DestTp': 'sw1p5s4'},
#    {'fabrics:LinkID': '11049',
#     'fabrics:SourceNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#     'fabrics:SourceTp': 'sw1p3s2',
#     'fabrics:DestNode': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#     'fabrics:DestTp': 'sw1p15s2'},
#    {'fabrics:LinkID': '11050',
#     'fabrics:SourceNode': 'c33539d8-1ea5-4d4e-887f-2e5801d6d546',
#     'fabrics:SourceTp': 'sw1p15s2',
#     'fabrics:DestNode': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#     'fabrics:DestTp': 'sw1p3s2'}],
#   'fabrics:Slice': [{'fabrics:SliceID': '1',
#     'fabrics:TpMapping': [{'fabrics:TpID': '38635c81-0c0e-490a-8d6e-25bceee93f70',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p31s4'},
#      {'fabrics:TpID': '4524dc5c-1e37-48c2-a596-0ba2abb7ff19',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p29s3'},
#      {'fabrics:TpID': '6302efb9-3925-4e94-873a-547f988c27d3',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p31s1'},
#      {'fabrics:TpID': '151538ec-01a1-410e-88d6-3ef7a1cf68ef',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p31s2'},
#      {'fabrics:TpID': 'c42e71ce-9ab3-4bfc-a8f2-a82a36450cc9',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p21s2'},
#      {'fabrics:TpID': '4f84e507-5da5-4865-8daf-f12045b3cb04',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p31s1'},
#      {'fabrics:TpID': 'af2fdf3f-3d34-4768-b19b-3730aa134942',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p31s3'},
#      {'fabrics:TpID': 'ec1f138f-87ce-49c1-9a86-4a92e240245b',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p31s3'},
#      {'fabrics:TpID': '323e6242-b988-401b-a44a-11bd1374a9f8',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p21s1'},
#      {'fabrics:TpID': '9dfc3542-d6a0-4114-9313-3f2589f2e2a9',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p21s3'},
#      {'fabrics:TpID': '6893b948-5f79-47dc-a015-c912f2431b8a',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p21s4'},
#      {'fabrics:TpID': '757c8f40-95be-4974-9be7-3f8801d04512',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p31s2'}]},
#    {'fabrics:SliceID': '2',
#     'fabrics:TpMapping': [{'fabrics:TpID': '4c09890e-3343-489c-ab78-708f1869ce44',
#       'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:TpRef': 'sw1p31s3'},
#      {'fabrics:TpID': '61c62b1e-562e-40d7-b502-27913ca4064d',
#       'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:TpRef': 'sw1p31s4'},
#      {'fabrics:TpID': '16741fae-8431-431f-bbaf-cd42ebd9b215',
#       'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:TpRef': 'sw1p31s1'},
#      {'fabrics:TpID': '95f7435c-edcc-46d2-81d1-b90c5abb6273',
#       'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:TpRef': 'sw1p31s2'},
#      {'fabrics:TpID': 'ba26ede3-3ae6-4514-9641-45294938c499',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p29s2'},
#      {'fabrics:TpID': '00f7e862-ff94-408f-9013-93d539fa16bc',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p23s2'},
#      {'fabrics:TpID': '7abaeb04-4e49-4f76-b503-46c4c5351983',
#       'fabrics:NodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#       'fabrics:TpRef': 'sw1p23s2'}]},
#    {'fabrics:SliceID': '3',
#     'fabrics:TpMapping': [{'fabrics:TpID': '1a9cceca-abc7-4b5d-b144-1f73daaaf339',
#       'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:TpRef': 'sw1p31s1'},
#      {'fabrics:TpID': '267a8633-57c2-4220-8de2-4be3f80da043',
#       'fabrics:NodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#       'fabrics:TpRef': 'sw1p31s2'},
#      {'fabrics:TpID': '3ccd5d78-ca51-49ba-b6cb-ca79c6940d62',
#       'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:TpRef': 'sw1p31s3'},
#      {'fabrics:TpID': 'a7b71b54-89bd-4c76-9072-0f021638c79a',
#       'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#       'fabrics:TpRef': 'sw1p31s4'},
#      {'fabrics:TpID': '45013883-fb74-4db1-9756-d3a6c3eda778',
#       'fabrics:NodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#       'fabrics:TpRef': 'sw1p29s1'}]},
#    {'fabrics:SliceID': '65535',
#     'fabrics:TpMapping': {'fabrics:TpID': 'b8bf39c3-805f-449e-984e-a9b8349b1e9f',
#      'fabrics:NodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#      'fabrics:TpRef': 'sw1p25s4'}}],
#   'fabrics:DNSServer': [{'fabrics:IPAddr': '10.0.30.146'},
#    {'fabrics:IPAddr': 'fd50:f:a:b::146'}],
#   'fabrics:NtpServer': [{'fabrics:IpAddr': '10.0.30.146',
#     'fabrics:MinPoll': '6',
#     'fabrics:MaxPoll': '10'},
#    {'fabrics:IpAddr': 'fd50:f:a:b::146',
#     'fabrics:MinPoll': '6',
#     'fabrics:MaxPoll': '10'}]},
#  'fabrics:VirtualFabric': [{'fabrics:VFabricID': '65535',
#    'fabrics:Name': 'DCIP_VirtualFabric',
#    'fabrics:Status': 'CREATED',
#    'fabrics:ManagementIPv4Address': '10.0.20.151',
#    'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::3',
#    'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#     'fabrics:Status': 'running',
#     'fabrics:IPv4Address': '10.0.20.157',
#     'fabrics:IPv6Address': '2602:807:900e:1d2::9'},
#    'fabrics:VirtualTerminationPoint': {'fabrics:FabricRef': '123',
#     'fabrics:NodeRef': '65535',
#     'fabrics:TpRef': 'b8bf39c3-805f-449e-984e-a9b8349b1e9f',
#     'fabrics:SupportingFabricRef': '123',
#     'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#     'fabrics:SupportingTpRef': 'sw1p25s4',
#     'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}},
#   {'fabrics:VFabricID': '1',
#    'fabrics:Name': 'ZeroTrust',
#    'fabrics:Status': 'CREATED',
#    'fabrics:ManagementIPv4Address': '10.0.20.158',
#    'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::a',
#    'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#     'fabrics:Status': 'stopped',
#     'fabrics:IPv4Address': '10.0.20.159',
#     'fabrics:IPv6Address': '2602:807:900e:1d2::b'},
#    'fabrics:VirtualTerminationPoint': [{'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '38635c81-0c0e-490a-8d6e-25bceee93f70',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p31s4',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '4524dc5c-1e37-48c2-a596-0ba2abb7ff19',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p29s3',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '6302efb9-3925-4e94-873a-547f988c27d3',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p31s1',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '151538ec-01a1-410e-88d6-3ef7a1cf68ef',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p31s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': 'c42e71ce-9ab3-4bfc-a8f2-a82a36450cc9',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p21s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '4f84e507-5da5-4865-8daf-f12045b3cb04',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p31s1',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': 'af2fdf3f-3d34-4768-b19b-3730aa134942',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p31s3',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': 'ec1f138f-87ce-49c1-9a86-4a92e240245b',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p31s3',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '323e6242-b988-401b-a44a-11bd1374a9f8',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p21s1',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '9dfc3542-d6a0-4114-9313-3f2589f2e2a9',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p21s3',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '6893b948-5f79-47dc-a015-c912f2431b8a',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p21s4',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '1',
#      'fabrics:TpRef': '757c8f40-95be-4974-9be7-3f8801d04512',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p31s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}]},
#   {'fabrics:VFabricID': '2',
#    'fabrics:Name': 'OpenStack_NET53',
#    'fabrics:Status': 'CREATED',
#    'fabrics:ManagementIPv4Address': '10.0.20.160',
#    'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::c',
#    'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#     'fabrics:Status': 'running',
#     'fabrics:IPv4Address': '10.0.20.161',
#     'fabrics:IPv6Address': '2602:807:900e:1d2::d'},
#    'fabrics:VirtualTerminationPoint': [{'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': '4c09890e-3343-489c-ab78-708f1869ce44',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#      'fabrics:SupportingTpRef': 'sw1p31s3',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': '61c62b1e-562e-40d7-b502-27913ca4064d',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#      'fabrics:SupportingTpRef': 'sw1p31s4',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': '16741fae-8431-431f-bbaf-cd42ebd9b215',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#      'fabrics:SupportingTpRef': 'sw1p31s1',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': '95f7435c-edcc-46d2-81d1-b90c5abb6273',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#      'fabrics:SupportingTpRef': 'sw1p31s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': 'ba26ede3-3ae6-4514-9641-45294938c499',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p29s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': '00f7e862-ff94-408f-9013-93d539fa16bc',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p23s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '2',
#      'fabrics:TpRef': '7abaeb04-4e49-4f76-b503-46c4c5351983',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '53bda0a6-0ef4-4647-8386-cf56a519c943',
#      'fabrics:SupportingTpRef': 'sw1p23s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}]},
#   {'fabrics:VFabricID': '3',
#    'fabrics:Name': 'OpenStack_NET52',
#    'fabrics:Status': 'CREATED',
#    'fabrics:ManagementIPv4Address': '10.0.20.162',
#    'fabrics:ManagementIPv6Address': '2602:807:900e:1d2::e',
#    'fabrics:GUI': {'fabrics:AllowEnable': 'true',
#     'fabrics:Status': 'running',
#     'fabrics:IPv4Address': '10.0.20.163',
#     'fabrics:IPv6Address': '2602:807:900e:1d2::f'},
#    'fabrics:VirtualTerminationPoint': [{'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '3',
#      'fabrics:TpRef': '1a9cceca-abc7-4b5d-b144-1f73daaaf339',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#      'fabrics:SupportingTpRef': 'sw1p31s1',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '3',
#      'fabrics:TpRef': '267a8633-57c2-4220-8de2-4be3f80da043',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '4a1a5430-1ca9-4f86-bc69-e2b39aba2db6',
#      'fabrics:SupportingTpRef': 'sw1p31s2',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '3',
#      'fabrics:TpRef': '3ccd5d78-ca51-49ba-b6cb-ca79c6940d62',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#      'fabrics:SupportingTpRef': 'sw1p31s3',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '3',
#      'fabrics:TpRef': 'a7b71b54-89bd-4c76-9072-0f021638c79a',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': 'a406445a-a733-4488-9089-53b7d69c8191',
#      'fabrics:SupportingTpRef': 'sw1p31s4',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'},
#     {'fabrics:FabricRef': '123',
#      'fabrics:NodeRef': '3',
#      'fabrics:TpRef': '45013883-fb74-4db1-9756-d3a6c3eda778',
#      'fabrics:SupportingFabricRef': '123',
#      'fabrics:SupportingNodeRef': '1003a9d7-6ed1-4bf2-b8f6-86622018882d',
#      'fabrics:SupportingTpRef': 'sw1p29s1',
#      'fabrics:DeploymentState': 'DEPLOYMENT_COMPLETED'}]}]}

# %%
a
# Out:
# '<rpc-reply xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="urn:uuid:7c5a48bd-6f76-4c00-9500-afd9c94bd4a0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0"><data xmlns:fabrics="urn:kaloom:faas:fabrics" xmlns:pa="urn:kaloom:faas:port-attributes"><fabrics:telemetry-system><fabrics:enabled>true</fabrics:enabled><fabrics:collector><fabrics:address>192.168.40.60</fabrics:address><fabrics:port>4171</fabrics:port><fabrics:next-hop-mac-address>52:93:8e:e6:96:e0</fabrics:next-hop-mac-address></fabrics:collector><fabrics:flow><fabrics:name>POSTECH_INT</fabrics:name><fabrics:priority>1</fabrics:priority><fabrics:destination-address-prefix>192.168.53.107/32</fabrics:destination-address-prefix><fabrics:exclude-filter>false</fabrics:exclude-filter><fabrics:sample-percentage
ressCount><fabrics:AdminState>UP</fabrics:AdminState><fabrics:OperState>UP</fabrics:OperState><fabrics:System><fabrics:SystemUptime>08:10:37 up 14 days,  5:30,  0 users,  load average: 3.85, 3.43, 3.26</fabrics:SystemUptime><fabrics:SystemClock>Mon Oct 31 08:10:37 UTC 2022</fabrics:SystemClock><fabrics:SystemMemory><fabrics:MemTotal>8043648</fabrics:MemTotal><fabrics:MemFree>79328</fabrics:MemFree><fabrics:Cached>4452992</fabrics:Cached><fabrics:SwapCached>0</fabrics:SwapCac ...

# %%
xmltodict.parse(str)
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 xmltodict.parse(str)
#
# File ~\anaconda3\lib\site-packages\xmltodict.py:378, in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, process_comments, **kwargs)
#     376     parser.Parse(b'',True)
#     377 else:
# --> 378     parser.Parse(xml_input, True)
#     379 return handler.item
#
# ExpatError: junk after document element: line 1, column 1232

# %%
pip install ncclient
# Out:
# Collecting ncclientNote: you may need to restart the kernel to use updated packages.
#   Downloading ncclient-0.6.13.tar.gz (105 kB)
# Requirement already satisfied: setuptools>0.6 in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (61.2.0)
# Requirement already satisfied: paramiko>=1.15.0 in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (2.8.1)
#
# Requirement already satisfied: lxml>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (4.8.0)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from ncclient) (1.16.0)
# Requirement already satisfied: pynacl>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient) (1.4.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\users\hp\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient) (3.2.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient) (3.4.8)
# Requirement already satisfied: cffi>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (2.21)
# Building wheels for collected packages: ncclient
#   Building wheel for ncclient (setup.py): started
#   Building wheel for ncclient (setup.py): finished with status 'done'
#   Created wheel for ncclient: filename=ncclient-0.6.13-py2.py3-none-any.whl size=84645 sha256=b9de5b910b7fa1aa9a1cd3e6b8135c6226d548d27c3d06a67bc8e1c1ec3c8bab
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\09\6a\19\71c39c626047324b1b4a66766ea7d03123d3cb1f8f1c2233d8
# Successfully built ncclient
# Installing collected packages: ncclient
# Successfully installed ncclient-0.6.13

# %%
pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
c.parse()

# %%
m.connected
# Out:
# False

# %%
c
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><data xmlns:fabrics="urn:kaloom:faas:fabrics" xmlns:pa="urn:kaloom:faas:port-attributes" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0"><fabrics:telemetry-system><fabrics:enabled>true</fabrics:enabled><fabrics:collector><fabrics:address>192.168.40.60</fabrics:address><fabrics:port>4171</fabrics:port><fabrics:next-hop-mac-address>52:93:8e:e6:96:e0</fabrics:next-hop-mac-address></fabrics:collector><fabrics:flow><fabrics:name>POSTECH_INT</fabrics:name><fabrics:priority>1</fabrics:priority><fabrics:destination-address-prefix>192.168.53.107/32</fabrics:destination-address-prefix><fabrics:exclude-filter>false</fabrics:exclude-filter><fabrics:sample-percentage>100</fabrics:sample-percentage></fabrics:flow><fabrics:flow><fabrics:name>ICMP_TEST</fabrics:name><fabrics:priority>3</fabrics:priority><fabrics:destination-address-prefix>0.0.0.0/0</fabrics:destination-address-prefix><fabrics:protocol>1</fabrics:protocol><fabrics:exclude-filter>false</fabrics:exclude-filter><fabrics:sample-percentage