# %%
import openstack
import pprint

openstack.enable_logging(debug=False)

pp=pprint.PrettyPrinter()
conn = openstack.connect(cloud='admin')

#for server in conn.compute.servers(all_projects=True):
#    server_info=server.to_dict()
#    print({
#        "name":server_info['name'],
#        "host":server_info['compute_host'],
#        "host_id":server_info['host_id']
#    })
    #pp.pprint(server)

# %%
from opstk_topology import *

# %%
host_server_dict
# Out:
# {'compute2.forwiz-os.com': [{'name': 'pss_lv_mg_test',
#    'vm_id': '2ae44f46-7f04-4280-87f7-0fdf10f75a29',
#    'vm_state': 'active',
#    'location': Munch({'cloud': 'admin', 'region_name': '', 'zone': 'nova', 'project': Munch({'id': '925aba3de85a48ccb284bf02edc1c18e', 'name': None, 'domain_id': None, 'domain_name': None})}),
#    'addresses': {'provider': [{'OS-EXT-IPS-MAC:mac_addr': 'fa:16:3e:db:6b:9d',
#       'version': 4,
#       'addr': '192.168.53.168',
#       'OS-EXT-IPS:type': 'fixed'}]}},
#   {'name': 'Grafana',
#    'vm_id': '2f70f301-b039-42cc-b043-1ed47011e1a8',
#    'vm_state': 'active',
#    'location': Munch({'cloud': 'admin', 'region_name': '', 'zone': 'nova', 'project': Munch({'id': 'a8e14f37c44d460788ce9fa9d825b5c9', 'name': 'admin', 'domain_id': None, 'domain_name': 'Default'})}),
#    'addresses': {'mgmt': [{'OS-EXT-IPS-MAC:mac_addr': 'fa:16:3e:e4:64:00',
#       'version': 4,
#       'addr': '192.168.15.184',
#       'OS-EXT-IPS:type': 'fixed'}]}},
# ...

# %%
#ports on vms

vm_id_dict={}
for server in conn.compute.servers(all_projects=True):
    vm_info=server.to_dict()
    vm_id=vm_info['id']
    vm_id_dict[vm_id]={'name':vm_info['name'], 'ports': []}

ports=conn.network.ports()
for port in ports: 
    dev_id=port['device_id']
    if dev_id in vm_id_dict:
        port_id=port['id']
        port_ip=port['fixed_ips'][0]['ip_address']
        port_subnet=port['fixed_ips'][0]['subnet_id']
        port_network_id=port['network_id']
        port_info={"id": port_id,
                   "ip": port_ip,
                  "subnet_id": port_subnet,
                  "net_id": port_network_id}
        vm_id_dict[dev_id]['ports'].append(port_info)
        #pp.pprint((dev_id, vm_id_dict[dev_id]['name']))
    else:
        pass
        #print ((dev_id, "non vm"))

# %%
pp.pprint(vm_id_dict)
# Out:
# {'066cd82c-c88b-4686-b761-6321a610e58a': {'name': 'amphora-8b443241-78b7-4529-99bb-165115e48104',
#                                           'ports': [{'id': '74fe2544-bfff-43e2-bd03-f96b498b37a2',
#                                                      'ip': '10.0.11.159',
#                                                      'net_id': '50afd675-baf5-4bb6-824b-efff5f63913d',
#                                                      'subnet': '27e1267b-c000-4c90-9b71-2ba22b4ff835'},
#                                                     {'id': 'b99fd591-42fe-446c-8eb9-b3ae206bc4d5',
#                                                      'ip': '192.168.53.142',
#                                                      'net_id': 'd64dbfc6-46de-4f2c-8b65-12c9d29a8b7e',
#                                                      'subnet': '16783d93-e2d7-4cc4-8cb3-ee33649a1564'}]},
#  '1baa87f1-adc0-4e7e-95e3-06e77d77381b': {'name': 'server',
# ...

# %%
host_server_dict={}

for server in conn.compute.servers(all_projects=True):
    server_info=server.to_dict()
    server_sum = {
        "name":server_info['name'],
        "vm_id":server_info['id'],
        "vm_state":server_info['vm_state'],
        "location":server_info['location'],
        "addresses":server_info['addresses'],
        #"hostname":server_info['hostname'],
        #"host_id":server_info['host_id']
    }
    host=server_info["compute_host"]
    if host not in host_server_dict:
        host_server_dict[host]=[]
    host_server_dict[host].append(server_sum)
    #pp.pprint(server)
    print(server_sum["name"])
    pp.pprint(list(conn.compute.server_interfaces(server)))
# Out:
# pss_lv_mg_test
# [{'fixed_ips': [{'ip_address': '192.168.53.168',
#                  'subnet_id': '16783d93-e2d7-4cc4-8cb3-ee33649a1564'}],
#   'id': 'b0579a38-998d-49c2-a0e9-40018f070432',
#   'location': {'cloud': 'admin',
#                'project': {'domain_id': None,
#                            'domain_name': 'Default',
#                            'id': 'a8e14f37c44d460788ce9fa9d825b5c9',
#                            'name': 'admin'},
#                'region_name': '',
#                'zone': None},
#   'mac_addr': 'fa:16:3e:db:6b:9d',
#   'name': None,
#   'net_id': 'd64dbfc6-46de-4f2c-8b65-12c9d29a8b7e',
#   'port_id': 'b0579a38-998d-49c2-a0e9-40018f070432',
#   'port_state': 'ACTIVE',
#   'server_id': None}]
# Grafana
# [{'fixed_ips': [{'ip_address': '192.168.15.184',
#                  'subnet_id': '2d13b9ea-55ae-442e-9837-8d856940dad2'}],
#   'id': 'a3777ca0-a311-4a20-944d-6d52a0758b1d',
#   'location': {'cloud': 'admin',
#                'project': {'domain_id': None,
# ...

# %%
host_server_dict={}

for server in conn.compute.servers(all_projects=True):
    pp.pprint(list(conn.compute.server_interfaces(server)))
# Out:
# [{'fixed_ips': [{'ip_address': '192.168.53.168',
#                  'subnet_id': '16783d93-e2d7-4cc4-8cb3-ee33649a1564'}],
#   'id': 'b0579a38-998d-49c2-a0e9-40018f070432',
#   'location': {'cloud': 'admin',
#                'project': {'domain_id': None,
#                            'domain_name': 'Default',
#                            'id': 'a8e14f37c44d460788ce9fa9d825b5c9',
#                            'name': 'admin'},
#                'region_name': '',
#                'zone': None},
#   'mac_addr': 'fa:16:3e:db:6b:9d',
#   'name': None,
#   'net_id': 'd64dbfc6-46de-4f2c-8b65-12c9d29a8b7e',
#   'port_id': 'b0579a38-998d-49c2-a0e9-40018f070432',
#   'port_state': 'ACTIVE',
#   'server_id': None}]
# [{'fixed_ips': [{'ip_address': '192.168.15.184',
#                  'subnet_id': '2d13b9ea-55ae-442e-9837-8d856940dad2'}],
#   'id': 'a3777ca0-a311-4a20-944d-6d52a0758b1d',
#   'location': {'cloud': 'admin',
#                'project': {'domain_id': None,
# ...

# %%
for server in conn.compute.servers(all_projects=True, details=True):
    server_info=server.to_dict()
    pp.pprint(server_info)
# Out:
# {'access_ipv4': '',
#  'access_ipv6': '',
#  'addresses': {'provider': [{'OS-EXT-IPS-MAC:mac_addr': 'fa:16:3e:db:6b:9d',
#                              'OS-EXT-IPS:type': 'fixed',
#                              'addr': '192.168.53.168',
#                              'version': 4}]},
#  'admin_password': None,
#  'attached_volumes': [{'delete_on_termination': False,
#                        'id': '56029559-fe07-4949-a6a1-6bf9a08b540b'}],
#  'availability_zone': 'nova',
#  'block_device_mapping': None,
#  'compute_host': 'compute3.forwiz-os.com',
#  'config_drive': '',
#  'created_at': '2022-11-11T08:44:41Z',
#  'description': None,
#  'disk_config': 'AUTO',
#  'flavor': {'disk': 20,
#             'ephemeral': 0,
#             'extra_specs': {'hw:vif_multiqueue_enabled': 'true'},
#             'original_name': 'm1.small',
#             'ram': 2048,
#             'swap': 0,
#             'vcpus': 1},
#  'flavor_id': None,
#  'has_config_drive': '',
# ...

# %%
server_info
# Out:
# {'links': [{'href': 'http://192.168.15.40:8774/v2.1/a8e14f37c44d460788ce9fa9d825b5c9/servers/b1660fd2-ab98-4455-86ef-3f24f91f0552',
#    'rel': 'self'},
#   {'href': 'http://192.168.15.40:8774/a8e14f37c44d460788ce9fa9d825b5c9/servers/b1660fd2-ab98-4455-86ef-3f24f91f0552',
#    'rel': 'bookmark'}],
#  'access_ipv4': '',
#  'access_ipv6': '',
#  'addresses': {'Net1': [{'OS-EXT-IPS-MAC:mac_addr': 'fa:16:3e:49:46:6a',
#     'version': 4,
#     'addr': '10.10.0.155',
#     'OS-EXT-IPS:type': 'fixed'},
#    {'OS-EXT-IPS-MAC:mac_addr': 'fa:16:3e:49:46:6a',
#     'version': 4,
#     'addr': '192.168.53.156',
#     'OS-EXT-IPS:type': 'floating'}]},
#  'admin_password': None,
#  'attached_volumes': [{'id': '930f8b36-61e1-4546-89dc-4befbf9be0a9',
#    'delete_on_termination': False}],
#  'availability_zone': 'nova',
#  'block_device_mapping': None,
#  'config_drive': '',
#  'compute_host': 'compute3.forwiz-os.com',
#  'created_at': '2022-08-24T07:29:14Z',
#  'description': None,
# ...

# %%
pp.pprint(host_server_dict)
# Out:
# {'compute1.forwiz-os.com': [{'addresses': {'provider': [{'OS-EXT-IPS-MAC:mac_addr': 'fa:16:3e:db:6b:9d',
#                                                          'OS-EXT-IPS:type': 'fixed',
#                                                          'addr': '192.168.53.168',
#                                                          'version': 4}]},
#                              'location': {'cloud': 'admin',
#                                           'project': {'domain_id': None,
#                                                       'domain_name': None,
#                                                       'id': '925aba3de85a48ccb284bf02edc1c18e',
#                                                       'name': None},
#                                           'region_name': '',
#                                           'zone': 'nova'},
#                              'name': 'pss_lv_mg_test',
#                              'vm_id': '2ae44f46-7f04-4280-87f7-0fdf10f75a29',
# ...

# %%
hypervisor_array=[]
for hypervisor in conn.compute.hypervisors(details=True):
    hypervisor_info=hypervisor.to_dict()
    hypervisor_array.append(hypervisor)

# %%
mg_vm_id="2ae44f46-7f04-4280-87f7-0fdf10f75a29"
try:
    mg_result=conn.compute.live_migrate_server(None, host3="compute1.forwiz-os.com", force=False, block_migration=None)
    #mg_result=conn.compute.live_migrate_server("2ae44f46-7f04-4280-87f7-0fdf10f75a29", force=False, block_migration=None)
except openstack.exceptions.BadRequestException as err: 
    print(err)
except openstack.exceptions.ResourceNotFound as err:
    print(err)
except:
    print("else")
# Out:
# else

# %%
mg_result

# %%
networks=conn.network.networks()
subnets=conn.network.subnets()

network_dict={}
subnet_dict={}

for subnet in subnets:
    subnet_id=subnet['id']
    subnet_cidr=subnet['cidr']
    subnet_name=subnet['name']
    subnet_gw=subnet['gateway_ip']
    
    subnet_dict[subnet_id]={}
    subnet_dict[subnet_id]['cidr']=subnet_cidr
    subnet_dict[subnet_id]['name']=subnet_name
    subnet_dict[subnet_id]['gw']=subnet_gw

for network in networks: 
    network_id=network['id']
    network_location=network['location']
    network_name=network['name']
    network_subnet_list=network['subnet_ids']
    
    network_dict[network_id]={}
    cur_dict=network_dict[network_id]
    cur_dict['name']=network_name
    cur_dict['location']=network_location
    cur_dict['subnet_dict']={}
    for subnet_id in network_subnet_list:
        subnet_info=subnet_dict[subnet_id]
        cur_dict['subnet_dict'][subnet_id]=subnet_info

#pp.pprint(subnet_dict)
pp.pprint(network_dict)
# Out:
# {'50afd675-baf5-4bb6-824b-efff5f63913d': {'location': {'cloud': 'admin',
#                                                        'project': {'domain_id': None,
#                                                                    'domain_name': None,
#                                                                    'id': '925aba3de85a48ccb284bf02edc1c18e',
#                                                                    'name': None},
#                                                        'region_name': '',
#                                                        'zone': None},
#                                           'name': 'ssn_web',
#                                           'subnet_dict': {'27e1267b-c000-4c90-9b71-2ba22b4ff835': {'cidr': '10.0.11.0/24',
#                                                                                                    'gw': '10.0.11.1',
# ...

# %%
subnets=conn.network.subnets()
for subnet in subnets: 
    pp.pprint(subnet)
# Out:
# {'allocation_pools': [{'end': '192.168.53.199', 'start': '192.168.53.100'}],
#  'cidr': '192.168.53.0/24',
#  'created_at': '2022-08-16T06:28:43Z',
#  'description': '',
#  'dns_nameservers': ['168.126.63.1'],
#  'gateway_ip': '192.168.53.254',
#  'host_routes': [],
#  'id': '16783d93-e2d7-4cc4-8cb3-ee33649a1564',
#  'ip_version': 4,
#  'ipv6_address_mode': None,
#  'ipv6_ra_mode': None,
#  'is_dhcp_enabled': True,
#  'location': {'cloud': 'admin',
#               'project': {'domain_id': None,
#                           'domain_name': 'Default',
#                           'id': 'a8e14f37c44d460788ce9fa9d825b5c9',
#                           'name': 'admin'},
#               'region_name': '',
#               'zone': None},
#  'name': 'provider_subnet',
#  'name': 'provider_subnet',
#  'network_id': 'd64dbfc6-46de-4f2c-8b65-12c9d29a8b7e',
#  'prefix_length': None,
#  'project_id': 'a8e14f37c44d460788ce9fa9d825b5c9',
#  'revision_number': 0,
#  'segment_id': None,
# ...

# %%
subnets=conn.network.ports()
for subnet in subnets: 
    pp.pprint(subnet)
# Out:
# {'allowed_address_pairs': [],
#  'binding_host_id': 'compute3.forwiz-os.com',
#  'binding_profile': {},
#  'binding_vif_details': {'bridge_name': 'br-int',
#                          'connectivity': 'l2',
#                          'datapath_type': 'system',
#                          'ovs_hybrid_plug': True,
#                          'port_filter': True},
#  'binding_vif_type': 'ovs',
#  'binding_vnic_type': 'normal',
#  'created_at': '2022-08-30T08:02:13Z',
#  'data_plane_status': None,
#  'description': '',
#  'device_id': '1e6c7143-3ea5-4a5a-b52e-541e2843a6b4',
#  'device_owner': 'compute:nova',
#  'dns_assignment': None,
#  'dns_domain': None,
#  'dns_name': None,
#  'extra_dhcp_opts': [],
#  'fixed_ips': [{'ip_address': '10.10.0.47',
#                 'subnet_id': 'ad382bf9-133d-47a2-bb7b-7654e75bdc95'}],
#  'id': '003c3364-c50e-4862-be02-5cfab755c226',
#  'is_admin_state_up': True,
#  'is_port_security_enabled': True,
#  'location': {'cloud': 'admin',
# ...

# %%
for ips in conn.compute.server_ips('930f8b36-61e1-4546-89dc-4befbf9be0a9'):
    pp.pprint(ips)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 for ips in conn.compute.server_ips('930f8b36-61e1-4546-89dc-4befbf9be0a9'):
#       2     pp.pprint(ips)
#
# File ~\anaconda3\lib\site-packages\openstack\compute\v2\server_ip.py:50, in ServerIP.list(cls, session, paginated, server_id, network_label, base_path, **params)
#      47 resp = resp.json()
#      49 if network_label is None:
# ---> 50     resp = resp[cls.resources_key]
#      52 for label, addresses in resp.items():
#      53     for address in addresses:
#
# KeyError: 'addresses'

# %%
{
  "compute3.forwiz-os.com": [
    {
      "name": "pss_lv_mg_test",
      "vm_id": "2ae44f46-7f04-4280-87f7-0fdf10f75a29",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "925aba3de85a48ccb284bf02edc1c18e",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:db:6b:9d",
            "version": 4,
            "addr": "192.168.53.168",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "jb_client",
      "vm_id": "4f2f1c28-0887-4642-9359-6e943d1dbd2b",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:0d:e1:04",
            "version": 4,
            "addr": "10.10.0.30",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:40:9a:aa",
            "version": 4,
            "addr": "192.168.53.193",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "VPN_Server",
      "vm_id": "a4487d3b-3cb3-4dec-b5c9-6cd946897abb",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "a8e14f37c44d460788ce9fa9d825b5c9",
          "name": "admin",
          "domain_id": null,
          "domain_name": "Default"
        }
      },
      "addresses": {
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:22:24:b3",
            "version": 4,
            "addr": "192.168.53.157",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "mgmt": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:c4:a6:9e",
            "version": 4,
            "addr": "192.168.15.174",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "test_server",
      "vm_id": "6978fb4d-98a9-4d16-b40e-fc2506353f22",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:4a:4f:9c",
            "version": 4,
            "addr": "10.10.0.215",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:ad:c4:f3",
            "version": 4,
            "addr": "192.168.53.113",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "client-3",
      "vm_id": "1e6c7143-3ea5-4a5a-b52e-541e2843a6b4",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:e9:8c:f0",
            "version": 4,
            "addr": "10.10.0.47",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:fd:73:47",
            "version": 4,
            "addr": "192.168.53.185",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "client-1",
      "vm_id": "8442a987-125b-4402-a12e-51a9f95d836c",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:1f:85:64",
            "version": 4,
            "addr": "10.10.0.205",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:c6:03:cf",
            "version": 4,
            "addr": "192.168.53.153",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "client-2",
      "vm_id": "fe302cec-e3e6-46aa-b85d-1a81d442fcb1",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:13:c5:6a",
            "version": 4,
            "addr": "10.10.0.159",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:29:0e:fe",
            "version": 4,
            "addr": "192.168.53.134",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "VNF3_Haproxy",
      "vm_id": "ada51b2e-5a2d-445a-91d4-5622f385e12d",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:b3:52:02",
            "version": 4,
            "addr": "10.10.0.227",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:38:f4:af",
            "version": 4,
            "addr": "192.168.53.158",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "server",
      "vm_id": "1baa87f1-adc0-4e7e-95e3-06e77d77381b",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:30:0f:0f",
            "version": 4,
            "addr": "10.10.0.233",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "VNF2_Suricata",
      "vm_id": "c853ca4c-c5af-461d-871c-94f8218d3d11",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:77:21:13",
            "version": 4,
            "addr": "10.10.0.141",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:17:a0:95",
            "version": 4,
            "addr": "192.168.53.118",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "VNF1_Firewall",
      "vm_id": "8b6f5ff6-379f-4fd4-b162-4a9a3ada8f65",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:ce:dd:b0",
            "version": 4,
            "addr": "10.10.0.79",
            "OS-EXT-IPS:type": "fixed"
          },
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:ce:dd:b0",
            "version": 4,
            "addr": "192.168.53.107",
            "OS-EXT-IPS:type": "floating"
          }
        ]
      }
    },
    {
      "name": "test",
      "vm_id": "b1660fd2-ab98-4455-86ef-3f24f91f0552",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "c85dd5fe44b346b7989b0f32ff07f2b8",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "Net1": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:49:46:6a",
            "version": 4,
            "addr": "10.10.0.155",
            "OS-EXT-IPS:type": "fixed"
          },
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:49:46:6a",
            "version": 4,
            "addr": "192.168.53.156",
            "OS-EXT-IPS:type": "floating"
          }
        ]
      }
    }
  ],
  "compute2.forwiz-os.com": [
    {
      "name": "Grafana",
      "vm_id": "2f70f301-b039-42cc-b043-1ed47011e1a8",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "a8e14f37c44d460788ce9fa9d825b5c9",
          "name": "admin",
          "domain_id": null,
          "domain_name": "Default"
        }
      },
      "addresses": {
        "mgmt": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:e4:64:00",
            "version": 4,
            "addr": "192.168.15.184",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "web-server",
      "vm_id": "59aeacf7-60ec-41c2-88bb-f1e75f15932c",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "925aba3de85a48ccb284bf02edc1c18e",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "ssn_web": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:42:cc:8f",
            "version": 4,
            "addr": "10.0.11.187",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "amphora-8b443241-78b7-4529-99bb-165115e48104",
      "vm_id": "066cd82c-c88b-4686-b761-6321a610e58a",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "1a7bba729edd45b5953c90e23397866c",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "provider": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:77:1c:d9",
            "version": 4,
            "addr": "192.168.53.142",
            "OS-EXT-IPS:type": "fixed"
          }
        ],
        "ssn_web": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:c5:62:5e",
            "version": 4,
            "addr": "10.0.11.159",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    },
    {
      "name": "test-web",
      "vm_id": "479c76f6-0cd4-4e31-81c4-bf26e34c9e41",
      "vm_state": "active",
      "location": {
        "cloud": "admin",
        "region_name": "",
        "zone": "nova",
        "project": {
          "id": "925aba3de85a48ccb284bf02edc1c18e",
          "name": null,
          "domain_id": null,
          "domain_name": null
        }
      },
      "addresses": {
        "ssn_web": [
          {
            "OS-EXT-IPS-MAC:mac_addr": "fa:16:3e:88:d8:25",
            "version": 4,
            "addr": "10.0.11.169",
            "OS-EXT-IPS:type": "fixed"
          }
        ]
      }
    }
  ]
}
